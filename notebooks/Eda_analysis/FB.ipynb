# %%
import sys
from pathlib import Path

# Add project root to path (one-time setup)
project_root = str(Path().resolve().parent.parent)  # Goes up to project_root/
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.corpus import stopwords
from src.eda_analysis import EdaAnalysis

# %% [markdown]
# ### create FB object

# %%
FB = EdaAnalysis(selected_stocks = ['FB'],input_path="../../data/raw_analyst_ratings.csv")

# %%
FB.load_data()
# Out:
# File loaded successfully. Shape: (1407328, 6)
# Filtered DataFrame shape of ['FB']: (380, 6)

# %%
FB.dataset_overview()
# Out:
#  =================== Dataset Overview:===================================
#         Unnamed: 0                                           headline  \
# 473873      476431  As Expected: Fed Keeps Rates Unchanged and For...
# 473874      476432  Facebook, Snap Analyst Projects Q2 Revenue Ups...
# 473875      476433  Tech Stocks And FAANGS Strong Again To Start D...
# 473876      476434  Big Tech Reaches New Record Heights At The Sto...
# 473877      476435  Twitter, Square Will Mark Juneteenth As Holida...
# 473878      476436                Afternoon Market Stats in 5 Minutes
# 473879      476437  Facebook shares are trading higher despite mar...
# 473880      476438  IRS Alerts Against Criminals Profiteering From...
# 473881      476439                  Morning Market Stats in 5 Minutes
# 473882      476440  Facebook-Backed Jio Platforms Gets $750M From ...
#
#                                                       url          publisher  \
# ...

# %%
FB.check_missing_value()
# Out:
# check for missing values
# Unnamed: 0    0
# headline      0
# url           0
# publisher     0
# date          0
# stock         0
# dtype: int64

# %%
FB.analyze_headline_lengths()
# Out:
# Headline length statistics:
# count    380.000000
# mean      87.413158
# std       46.016406
# min       26.000000
# 25%       61.000000
# 50%       76.000000
# 75%       93.250000
# max      290.000000
# Name: headline_length, dtype: float64

# %%
FB.count_number_article()
# Out:
# publisher
# Benzinga Newsdesk          102
# Neer Varshney               56
# Shivdeep Dhaliwal           29
# IAM Newswire                22
# JJ Kinahan                  21
# Vick Meyer                  20
# Lisa Levin                  19
# Benzinga Insights           16
# Wayne Duggan                12
# Jayson Derrick               9
# Benzinga_Newsdesk            9
# ETF Professor                7
# Tanzeel Akhtar               6
# Elizabeth Balboa             6
# Charles Gross                5
# vishwanath@benzinga.com      4
# Nelson Hem                   4
# Renato Capelj                3
# Crystal Mills                3
# Tyree Gorges                 3
# Shanthi Rexaline             3
# Spencer Israel               2
# Luke J Jacobi                2
# TD Ameritrade Network        2
# luke@benzinga.com            2
# Hasan Saleem                 1
# FreightWaves                 1
# Jaycee Tenn                  1
# Benzinga Staff               1
# ...

# %%
FB.top_publishers_plot()
# Out:
# Top 10 publishers:
# publisher
# Benzinga Newsdesk    102
# Neer Varshney         56
# Shivdeep Dhaliwal     29
# IAM Newswire          22
# JJ Kinahan            21
# Vick Meyer            20
# Lisa Levin            19
# Benzinga Insights     16
# Wayne Duggan          12
# Jayson Derrick         9
# Name: count, dtype: int64

# %%
FB.daily_article_trend()

# %% [markdown]
# ### Text Analysis using nltk

# %%
FB.text_analysis()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bekuman\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Time series Anlaysis

# %%
FB.daily_article_trend()

# %%
FB.article_hour_distribution()
# Out:
# D:\WEEK 1\financial-news-sentiment-correlation\src\eda_analysis.py:98: UserWarning: Glyph 9200 (\N{ALARM CLOCK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# d:\WEEK 1\financial-news-sentiment-correlation\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9200 (\N{ALARM CLOCK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### Publisher Analysis:

# %%
# email addresses are used as publisher names
FB.extract_email_domains()
# Out:
# Top contributing email domains:
# publisher_domain
# benzinga.com    6
# Name: count, dtype: int64
