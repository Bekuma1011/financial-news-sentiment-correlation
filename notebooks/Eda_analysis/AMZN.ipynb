# %%
import sys
from pathlib import Path

# Add project root to path (one-time setup)
project_root = str(Path().resolve().parent.parent)  # Goes up to project_root/
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.corpus import stopwords
from src.eda_analysis import EdaAnalysis

# %% [markdown]
# ### create  AMZN object

# %%
AMZN = EdaAnalysis(selected_stocks = ['AMZN'],input_path="../../data/raw_analyst_ratings.csv")

# %%
AMZN.load_data()
# Out:
# File loaded successfully. Shape: (1407328, 6)
# Filtered DataFrame shape of ['AMZN']: (278, 6)

# %%
AMZN.dataset_overview()
# Out:
#  =================== Dataset Overview:===================================
#        Unnamed: 0                                           headline  \
# 76177       76869  How Cannabis Company Cannaphyll Is Marketing O...
# 76178       76870  Tech Stocks And FAANGS Strong Again To Start D...
# 76179       76871  Benzinga Pro's Top 5 Stocks To Watch For Wed.,...
# 76180       76872  Hearing Vertical Group Out Positive On Amazon,...
# 76181       76873  Big Tech Reaches New Record Heights At The Sto...
# 76182       76874  Twitter, Square Will Mark Juneteenth As Holida...
# 76183       76875  'Inside Amazon's plan to test warehouse worker...
# 76184       76876  BofA Raises Amazon Target On Sales Upside, Acc...
# 76185       76877  Amazon shares are trading higher despite marke...
# 76186       76878  IRS Alerts Against Criminals Profiteering From...
#
#                                                      url          publisher  \
# 76177  https://www.benzinga.com/markets/cannabis/20/0...        Jaycee Tenn
# 76178  https://www.benzinga.com/government/20/06/1622...         JJ Kinahan
# 76179  https://www.benzinga.com/short-sellers/20/06/1...  Benzinga Newsdesk
# 76180  https://www.benzinga.com/analyst-ratings/analy...  Benzinga Newsdesk
# 76181  https://www.benzinga.com/news/20/06/16218615/b...      Neer Varshney
# 76182  https://www.benzinga.com/news/20/06/16218441/t...  Shivdeep Dhaliwal
# 76183  https://www.benzinga.com/news/20/06/16215412/i...  Benzinga Newsdesk
# 76184  https://www.benzinga.com/analyst-ratings/analy...        Priya Nigam
# 76185  https://www.benzinga.com/wiim/20/06/16213978/a...  Benzinga Newsdesk
# 76186  https://www.benzinga.com/government/20/06/1620...      Neer Varshney
#
#                             date stock
# 76177  2020-06-10 13:18:50-04:00  AMZN
# 76178  2020-06-10 11:33:26-04:00  AMZN
# 76179  2020-06-10 07:53:47-04:00  AMZN
# 76180  2020-06-10 07:20:03-04:00  AMZN
# 76181  2020-06-10 00:52:01-04:00  AMZN
# 76182  2020-06-10 00:28:00-04:00  AMZN
# 76183  2020-06-09 14:52:04-04:00  AMZN
# 76184  2020-06-09 12:35:22-04:00  AMZN
# 76185  2020-06-09 12:13:54-04:00  AMZN
# 76186  2020-06-09 11:36:51-04:00  AMZN
#
#  ============================== Last 5 Rows of the Dataset:========================
#        Unnamed: 0                                           headline  \
# 76450       77194      3 Sector ETFs For This Week's Earnings Parade
# 76451       77195  Amazon Statement Shows Co. Extends Closure Of ...
# 76452       77196  Will COVID-19 Accelerate The Adoption Of Auton...
# 76453       77197  SunTrust Robinson Humphrey Maintains Buy on Am...
# 76454       77198  Apple And Amazon Earnings, Fed Meeting Among H...
#
#                                                      url          publisher  \
# 76450  https://www.benzinga.com/news/earnings/20/04/1...      ETF Professor
# 76451  https://www.benzinga.com/news/20/04/15888140/a...  Benzinga Newsdesk
# 76452  https://www.benzinga.com/news/20/04/15887271/w...       FreightWaves
# 76453  https://www.benzinga.com/news/20/04/15885780/s...         Vick Meyer
# 76454  https://www.benzinga.com/news/earnings/20/04/1...         JJ Kinahan
#
#                       date stock
# 76450  2020-04-27 00:00:00  AMZN
# 76451  2020-04-27 00:00:00  AMZN
# 76452  2020-04-27 00:00:00  AMZN
# 76453  2020-04-27 00:00:00  AMZN
# 76454  2020-04-27 00:00:00  AMZN
#
#  ================================ Random Sample of 5 Rows:=============================
#        Unnamed: 0                                           headline  \
# 76268       77012  Q1 13F Roundup: How Buffett, Einhorn, Ackman A...
# 76272       77016  How Supply Chain Partners Can Help Drive The T...
# 76285       77029  Hearing KeyBanc Saying Amazon Launched Common ...
# 76297       77041  Caution Ahead: Biggest Blue-Chips Seek Change,...
# 76453       77197  SunTrust Robinson Humphrey Maintains Buy on Am...
#
#                                                      url          publisher  \
# 76268  https://www.benzinga.com/news/20/05/16051311/q...       Wayne Duggan
# 76272  https://www.benzinga.com/news/20/05/16047624/h...       FreightWaves
# 76285  https://www.benzinga.com/analyst-ratings/analy...  Benzinga Newsdesk
# 76297  https://www.benzinga.com/markets/20/05/1601240...       IAM Newswire
# 76453  https://www.benzinga.com/news/20/04/15885780/s...         Vick Meyer
#
#                       date stock
# 76268  2020-05-16 00:00:00  AMZN
# 76272  2020-05-15 00:00:00  AMZN
# 76285  2020-05-14 00:00:00  AMZN
# 76297  2020-05-12 00:00:00  AMZN
# 76453  2020-04-27 00:00:00  AMZN
#
#  =================================== Dataset Shape:=====================================
# (278, 6)
#
#  The description of the numeric columns:
#          Unnamed: 0
# count    278.000000
# mean   77057.629496
# std       84.028035
# min    76869.000000
# 25%    76990.250000
# 50%    77059.500000
# 75%    77128.750000
# max    77198.000000
# Check for missing values:
# Unnamed: 0    0
# headline      0
# url           0
# publisher     0
# date          0
# stock         0
# dtype: int64

# %%
AMZN.check_missing_value()
# Out:
# check for missing values
# Unnamed: 0    0
# headline      0
# url           0
# publisher     0
# date          0
# stock         0
# dtype: int64

# %%
AMZN.analyze_headline_lengths()
# Out:
# Headline length statistics:
# count    278.000000
# mean      81.255396
# std       38.166785
# min       29.000000
# 25%       58.000000
# 50%       75.000000
# 75%       91.000000
# max      254.000000
# Name: headline_length, dtype: float64

# %%
AMZN.count_number_article()
# Out:
# publisher
# Benzinga Newsdesk          67
# Neer Varshney              21
# FreightWaves               20
# JJ Kinahan                 19
# Lisa Levin                 17
# Shivdeep Dhaliwal          14
# IAM Newswire               13
# Vick Meyer                 13
# ETF Professor              10
# Charles Gross              10
# Jayson Derrick              8
# Wayne Duggan                8
# Benzinga_Newsdesk           8
# Crystal Mills               7
# Benzinga Insights           6
# Nelson Hem                  5
# Renato Capelj               4
# Tanzeel Akhtar              4
# Joel Elconin                4
# Elizabeth Balboa            2
# Priya Nigam                 2
# Craig Jones                 2
# TD Ameritrade               1
# vishwanath@benzinga.com     1
# Shanthi Rexaline            1
# Tyree Gorges                1
# Steve Krause                1
# Jaycee Tenn                 1
# The Fresh Toast             1
# AARP                        1
# Direxion                    1
# Dylan Wittenberg            1
# Eric Mancini                1
# Rich Worthington            1
# Luke J Jacobi               1
# Khyathi Dalal               1
# Name: count, dtype: int64

# %%
AMZN.top_publishers_plot()
# Out:
# Top 10 publishers:
# publisher
# Benzinga Newsdesk    67
# Neer Varshney        21
# FreightWaves         20
# JJ Kinahan           19
# Lisa Levin           17
# Shivdeep Dhaliwal    14
# IAM Newswire         13
# Vick Meyer           13
# ETF Professor        10
# Charles Gross        10
# Name: count, dtype: int64

# %%
AMZN.daily_article_trend()

# %% [markdown]
# ### Text Analysis using nltk

# %%
AMZN.text_analysis()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bekuman\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Time series Anlaysis

# %%
AMZN.daily_article_trend()

# %%
AMZN.article_hour_distribution()
# Out:
# D:\WEEK 1\financial-news-sentiment-correlation\src\eda_analysis.py:98: UserWarning: Glyph 9200 (\N{ALARM CLOCK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# d:\WEEK 1\financial-news-sentiment-correlation\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9200 (\N{ALARM CLOCK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### Publisher Analysis:

# %%
# email addresses are used as publisher names
AMZN.extract_email_domains()
# Out:
# Top contributing email domains:
# publisher_domain
# benzinga.com    1
# Name: count, dtype: int64
