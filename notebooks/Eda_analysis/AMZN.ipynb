# %%
import sys
from pathlib import Path

# Add project root to path (one-time setup)
project_root = str(Path().resolve().parent.parent)  # Goes up to project_root/
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.corpus import stopwords
from src.eda_analysis import EdaAnalysis

# %% [markdown]
# ### create  AMZN object

# %%
AMZN = EdaAnalysis(selected_stocks = ['AAPL'],input_path="../../data/raw_analyst_ratings.csv")

# %%
AMZN.load_data()
# Out:
# File loaded successfully. Shape: (1407328, 6)
# Filtered DataFrame shape of ['AAPL']: (441, 6)

# %%
AMZN.dataset_overview()
# Out:
#  =================== Dataset Overview:===================================
#       Unnamed: 0                                           headline  \
# 6680        7120  Tech Stocks And FAANGS Strong Again To Start D...
# 6681        7121      10 Biggest Price Target Changes For Wednesday
# 6682        7122  Benzinga Pro's Top 5 Stocks To Watch For Wed.,...
# 6683        7123  Deutsche Bank Maintains Buy on Apple, Raises P...
# 6684        7124  Apple To Let Users Trade In Their Mac Computer...
# 6685        7125  Big Tech Reaches New Record Heights At The Sto...
# 6686        7126          Why Apple's Stock Is Trading Higher Today
# 6687        7127  Apple Could Announce In-House Chips For Macs A...
# 6688        7128  Apple shares are trading higher despite market...
# 6689        7129  Sonos Shares Spike To Session High, Now Up 9.5...
#
#                                                     url          publisher  \
# ...

# %%
AMZN.check_missing_value()
# Out:
# check for missing values
# Unnamed: 0    0
# headline      0
# url           0
# publisher     0
# date          0
# stock         0
# dtype: int64

# %%
AMZN.analyze_headline_lengths()
# Out:
# Headline length statistics:
# count    441.000000
# mean      86.997732
# std       48.087019
# min       21.000000
# 25%       61.000000
# 50%       74.000000
# 75%       92.000000
# max      373.000000
# Name: headline_length, dtype: float64

# %%
AMZN.count_number_article()
# Out:
# publisher
# Benzinga Newsdesk        117
# Neer Varshney             47
# JJ Kinahan                37
# Lisa Levin                32
# IAM Newswire              25
# Charles Gross             25
# Benzinga_Newsdesk         22
# Vick Meyer                20
# Shivdeep Dhaliwal         20
# Shanthi Rexaline          13
# Nelson Hem                 9
# Tanzeel Akhtar             9
# Elizabeth Balboa           8
# Jayson Derrick             8
# Wayne Duggan               7
# Craig Jones                5
# Renato Capelj              5
# luke@benzinga.com          4
# ETF Professor              4
# Jason Shubnell             3
# FreightWaves               3
# Spencer Israel             3
# TD Ameritrade              3
# Benzinga Insights          2
# Tyree Gorges               1
# TD Ameritrade Network      1
# Henry Khederian            1
# Priya Nigam                1
# Othanas Economopoulos      1
# Howie Bick                 1
# Luis Aureliano             1
# ...

# %%
AMZN.top_publishers_plot()
# Out:
# Top 10 publishers:
# publisher
# Benzinga Newsdesk    117
# Neer Varshney         47
# JJ Kinahan            37
# Lisa Levin            32
# IAM Newswire          25
# Charles Gross         25
# Benzinga_Newsdesk     22
# Vick Meyer            20
# Shivdeep Dhaliwal     20
# Shanthi Rexaline      13
# Name: count, dtype: int64

# %%
AMZN.daily_article_trend()

# %% [markdown]
# ### Text Analysis using nltk

# %%
AMZN.text_analysis()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bekuman\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Time series Anlaysis

# %%
AMZN.daily_article_trend()

# %%
AMZN.article_hour_distribution()
# Out:
# D:\WEEK 1\financial-news-sentiment-correlation\src\eda_analysis.py:98: UserWarning: Glyph 9200 (\N{ALARM CLOCK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# d:\WEEK 1\financial-news-sentiment-correlation\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9200 (\N{ALARM CLOCK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### Publisher Analysis:

# %%
# email addresses are used as publisher names
AMZN.extract_email_domains()
