# %%
import sys
from pathlib import Path

# Add project root to path (one-time setup)
project_root = str(Path().resolve().parent.parent)  # Goes up to project_root/
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.corpus import stopwords
from src.eda_analysis import EdaAnalysis

# %% [markdown]
# ### create NVDA object

# %%
NVDA = EdaAnalysis(selected_stocks = ['NVDA'],input_path="../../data/raw_analyst_ratings.csv")

# %%
NVDA.load_data()
# Out:
# File loaded successfully. Shape: (1407328, 6)
# Filtered DataFrame shape of ['NVDA']: (3146, 6)

# %%
NVDA.dataset_overview()
# Out:
#  =================== Dataset Overview:===================================
#         Unnamed: 0                                           headline  \
# 924271      929039  Shares of several technology companies are tra...
# 924272      929040                Afternoon Market Stats in 5 Minutes
# 924273      929041                  Morning Market Stats in 5 Minutes
# 924274      929042  Shares of several technology companies are tra...
# 924275      929043                Afternoon Market Stats in 5 Minutes
# 924276      929044  Shares of some technology companies are tradin...
# 924277      929045                  Morning Market Stats in 5 Minutes
# 924278      929046  Why BofA Recommends Buying GPU Plays AMD and N...
# 924279      929047  Cramer Weighs In On Ciena, Harley-Davidson And...
# 924280      929048  Semiconductor Industry to Lobby for Billions t...
#
#                                                       url          publisher  \
# ...

# %%
NVDA.check_missing_value()
# Out:
# check for missing values
# Unnamed: 0    0
# headline      0
# url           0
# publisher     0
# date          0
# stock         0
# dtype: int64

# %%
NVDA.analyze_headline_lengths()
# Out:
# Headline length statistics:
# count    3146.000000
# mean       76.813732
# std        47.904001
# min        16.000000
# 25%        47.000000
# 50%        64.000000
# 75%        85.000000
# max       382.000000
# Name: headline_length, dtype: float64

# %%
NVDA.count_number_article()
# Out:
# publisher
# Lisa Levin           357
# Benzinga Newsdesk    346
# Paul Quintaro        293
# Charles Gross        191
# Wayne Duggan         144
#                     ...
# Patrick Williams       1
# Jake Mann              1
# Leigh Drogen           1
# Rebecca Sheppard       1
# Mark Page              1
# Name: count, Length: 152, dtype: int64

# %%
NVDA.top_publishers_plot()
# Out:
# Top 10 publishers:
# publisher
# Lisa Levin           357
# Benzinga Newsdesk    346
# Paul Quintaro        293
# Charles Gross        191
# Wayne Duggan         144
# Jayson Derrick       126
# Monica Gerson        126
# Shanthi Rexaline     118
# Benzinga_Newsdesk    107
# JJ Kinahan           101
# Name: count, dtype: int64

# %%
NVDA.daily_article_trend()

# %% [markdown]
# ### Text Analysis using nltk

# %%
NVDA.text_analysis()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bekuman\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Time series Anlaysis

# %%
NVDA.daily_article_trend()

# %%
NVDA.article_hour_distribution()
# Out:
# D:\WEEK 1\financial-news-sentiment-correlation\src\eda_analysis.py:98: UserWarning: Glyph 9200 (\N{ALARM CLOCK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# d:\WEEK 1\financial-news-sentiment-correlation\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9200 (\N{ALARM CLOCK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### Publisher Analysis:

# %%
# email addresses are used as publisher names
NVDA.extract_email_domains()
# Out:
# Top contributing email domains:
# publisher_domain
# benzinga.com    23
# gmail.com        1
# Name: count, dtype: int64
