# %%
import sys
from pathlib import Path

# Add project root to path (one-time setup)
project_root = str(Path().resolve().parent.parent)  # Goes up to project_root/
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.corpus import stopwords
from src.eda_analysis import EdaAnalysis

# %% [markdown]
# ### create MSF object

# %%
MSF = EdaAnalysis(selected_stocks = ['MSF'],input_path="../../data/raw_analyst_ratings.csv")

# %%
MSF.load_data()
# Out:
# File loaded successfully. Shape: (1407328, 6)
# Filtered DataFrame shape of ['MSF']: (12, 6)

# %%
MSF.dataset_overview()
# Out:
#  =================== Dataset Overview:===================================
#         Unnamed: 0                                           headline  \
# 857407      861769  NVIDIA with Microsoft Announces Technology Col...
# 857408      861770  LinkedIn to Acquire Glint, An Employee Engagem...
# 857409      861771  Stocks Which Set New 52-Week Low Yesterday, Se...
# 857410      861772  Stocks Which Set New 52-Week Low Yesterday, Se...
# 857411      861773  Stocks Which Set New 52-Week Low Friday, Septe...
# 857412      861774  Stocks Which Set New 52-Week Low Yesterday, Se...
# 857413      861775  Stocks Which Set New 52-Week Low Yesterday, Se...
# 857414      861776  Stocks Which Set New 52-Week Low Yesterday, Au...
# 857415      861777  UPDATE: Polygon Article Speculates Valve, PUBG...
# 857416      861778    Where The Top 5 Tech Firms Derive Their Revenue
#
#                                                       url          publisher  \
# ...

# %%
MSF.check_missing_value()
# Out:
# check for missing values
# Unnamed: 0    0
# headline      0
# url           0
# publisher     0
# date          0
# stock         0
# dtype: int64

# %%
MSF.analyze_headline_lengths()
# Out:
# Headline length statistics:
# count    12.000000
# mean     64.166667
# std      13.583635
# min      47.000000
# 25%      56.500000
# 50%      57.500000
# 75%      77.250000
# max      88.000000
# Name: headline_length, dtype: float64

# %%
MSF.count_number_article()
# Out:
# publisher
# Benzinga Newsdesk    7
# Charles Gross        1
# Paul Quintaro        1
# Brett Hershman       1
# Taylor Cox           1
# SmallCapVoice        1
# Name: count, dtype: int64

# %%
MSF.top_publishers_plot()
# Out:
# Top 10 publishers:
# publisher
# Benzinga Newsdesk    7
# Charles Gross        1
# Paul Quintaro        1
# Brett Hershman       1
# Taylor Cox           1
# SmallCapVoice        1
# Name: count, dtype: int64

# %%
MSF.daily_article_trend()

# %% [markdown]
# ### Text Analysis using nltk

# %%
MSF.text_analysis()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bekuman\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Time series Anlaysis

# %%
MSF.daily_article_trend()

# %%
MSF.article_hour_distribution()
# Out:
# D:\WEEK 1\financial-news-sentiment-correlation\src\eda_analysis.py:98: UserWarning: Glyph 9200 (\N{ALARM CLOCK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# d:\WEEK 1\financial-news-sentiment-correlation\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9200 (\N{ALARM CLOCK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### Publisher Analysis:

# %%
# email addresses are used as publisher names
MSF.extract_email_domains()
# Out:
# No email-format publishers were found.
