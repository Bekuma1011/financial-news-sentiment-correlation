# %%
import sys
from pathlib import Path

# Add project root to path (one-time setup)
project_root = str(Path().resolve().parent.parent)  # Goes up to project_root/
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.corpus import stopwords
from src.eda_analysis import EdaAnalysis

# %% [markdown]
# ### create GOOG object

# %%
GOOG = EdaAnalysis(selected_stocks = ['GOOG'],input_path="../../data/raw_analyst_ratings.csv")

# %%
GOOG.load_data()
# Out:
# File loaded successfully. Shape: (1407328, 6)
# Filtered DataFrame shape of ['GOOG']: (1199, 6)

# %%
GOOG.dataset_overview()
# Out:
#  =================== Dataset Overview:===================================
#         Unnamed: 0                                           headline  \
# 565380      568379  Facebook, Snap Analyst Projects Q2 Revenue Ups...
# 565381      568380  How Cannabis Company Cannaphyll Is Marketing O...
# 565382      568381  Twitter, Square Will Mark Juneteenth As Holida...
# 565383      568382             Price Over Earnings Overview: Alphabet
# 565384      568383  Google Maps To Offer Relevant Local COVID-19 I...
# 565385      568384  Starting This Week, Testing Center Alerts Will...
# 565386      568385  CNBC Publishes Article Titled: States are Lean...
# 565387      568386  Congress Is Stepping Up Its Efforts To Kill Pa...
# 565388      568387  Twitter Takes Down Trump Campaign's Video Trib...
# 565389      568388  UPDATE: Chinese Government-Linked Hackers Rece...
#
#                                                       url          publisher  \
# ...

# %%
GOOG.check_missing_value()
# Out:
# check for missing values
# Unnamed: 0    0
# headline      0
# url           0
# publisher     0
# date          0
# stock         0
# dtype: int64

# %%
GOOG.analyze_headline_lengths()
# Out:
# Headline length statistics:
# count    1199.000000
# mean       86.687239
# std        46.697582
# min        18.000000
# 25%        57.000000
# 50%        75.000000
# 75%        95.000000
# max       315.000000
# Name: headline_length, dtype: float64

# %%
GOOG.count_number_article()
# Out:
# publisher
# Benzinga Newsdesk          408
# Neer Varshney               68
# JJ Kinahan                  68
# Wayne Duggan                64
# Benzinga_Newsdesk           62
#                           ...
# Khyathi                      1
# Khyathi Dalal                1
# vishwanath@benzinga.com      1
# Eric Mancini                 1
# Spencer White                1
# Name: count, Length: 73, dtype: int64

# %%
GOOG.top_publishers_plot()
# Out:
# Top 10 publishers:
# publisher
# Benzinga Newsdesk    408
# Neer Varshney         68
# JJ Kinahan            68
# Wayne Duggan          64
# Benzinga_Newsdesk     62
# Jayson Derrick        52
# Lisa Levin            52
# Charles Gross         41
# Dave Royse            35
# ETF Professor         32
# Name: count, dtype: int64

# %%
GOOG.daily_article_trend()

# %% [markdown]
# ### Text Analysis using nltk

# %%
GOOG.text_analysis()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bekuman\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Time series Anlaysis

# %%
GOOG.daily_article_trend()

# %%
GOOG.article_hour_distribution()
# Out:
# D:\WEEK 1\financial-news-sentiment-correlation\src\eda_analysis.py:98: UserWarning: Glyph 9200 (\N{ALARM CLOCK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# d:\WEEK 1\financial-news-sentiment-correlation\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9200 (\N{ALARM CLOCK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### Publisher Analysis:

# %%
# email addresses are used as publisher names
GOOG.extract_email_domains()
# Out:
# Top contributing email domains:
# publisher_domain
# benzinga.com    9
# Name: count, dtype: int64
