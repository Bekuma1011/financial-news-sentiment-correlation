# %%
import sys
from pathlib import Path

# Add project root to path (one-time setup)
project_root = str(Path().resolve().parent.parent)  # Goes up to project_root/
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.corpus import stopwords
from src.eda_analysis import EdaAnalysis

# %% [markdown]
# ### create TSLAo bject

# %%
TSLA = EdaAnalysis(selected_stocks = ['TSLA'],input_path="../../data/raw_analyst_ratings.csv")

# %%
TSLA.load_data()
# Out:
# File loaded successfully. Shape: (1407328, 6)
# Filtered DataFrame shape of ['TSLA']: (1875, 6)

# %%
TSLA.dataset_overview()
# Out:
#  =================== Dataset Overview:===================================
#          Unnamed: 0                                           headline  \
# 1255221     1261140  Tesla's Stock Closes At All-Time High As Musk ...
# 1255222     1261141  'Tesla factory workplace safety is 5% better t...
# 1255223     1261142  'Tesla hacker unlocks Performance upgrade and ...
# 1255224     1261143  GM On Track To Spend $20B On EV And AV Develop...
# 1255225     1261144                  Tesla's Journey To $1,000 In 2020
# 1255226     1261145  Tesla Shares Mark Session And New All-Time Hig...
# 1255227     1261146  Wedbush Says Tesla Has 'Game Changing' Develop...
# 1255228     1261147  Wedbush Maintains Neutral on Tesla, Raises Pri...
# 1255229     1261148  Musk Says It's Time To Ramp Production Of Tesl...
# 1255230     1261149  Tesla shares are trading higher after Wedbush ...
#
#                                                        url          publisher  \
# ...

# %%
TSLA.check_missing_value()
# Out:
# check for missing values
# Unnamed: 0    0
# headline      0
# url           0
# publisher     0
# date          0
# stock         0
# dtype: int64

# %%
TSLA.analyze_headline_lengths()
# Out:
# Headline length statistics:
# count    1875.000000
# mean       87.247467
# std        47.142165
# min        19.000000
# 25%        60.000000
# 50%        75.000000
# 75%        95.000000
# max       337.000000
# Name: headline_length, dtype: float64

# %%
TSLA.count_number_article()
# Out:
# publisher
# Benzinga Newsdesk          641
# Charles Gross              188
# Lisa Levin                 173
# Benzinga_Newsdesk          102
# Neer Varshney               85
# Wayne Duggan                64
# FreightWaves                56
# JJ Kinahan                  53
# IAM Newswire                47
# Shivdeep Dhaliwal           44
# Dave Royse                  43
# Vick Meyer                  35
# Shanthi Rexaline            34
# Jayson Derrick              34
# Nelson Hem                  32
# Elizabeth Balboa            32
# Tanzeel Akhtar              32
# Craig Jones                 17
# ETF Professor               14
# Joel Elconin                13
# Renato Capelj               12
# Chris Dier-Scalise          11
# luke@benzinga.com           11
# Benzinga Insights           11
# TD Ameritrade Network        9
# Spencer Israel               8
# TD Ameritrade                7
# Amit Nag                     7
# Jason Shubnell               6
# ...

# %%
TSLA.top_publishers_plot()
# Out:
# Top 10 publishers:
# publisher
# Benzinga Newsdesk    641
# Charles Gross        188
# Lisa Levin           173
# Benzinga_Newsdesk    102
# Neer Varshney         85
# Wayne Duggan          64
# FreightWaves          56
# JJ Kinahan            53
# IAM Newswire          47
# Shivdeep Dhaliwal     44
# Name: count, dtype: int64

# %%
TSLA.daily_article_trend()

# %% [markdown]
# ### Text Analysis using nltk

# %%
TSLA.text_analysis()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bekuman\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Time series Anlaysis

# %%
TSLA.daily_article_trend()

# %%
TSLA.article_hour_distribution()
# Out:
# D:\WEEK 1\financial-news-sentiment-correlation\src\eda_analysis.py:98: UserWarning: Glyph 9200 (\N{ALARM CLOCK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# d:\WEEK 1\financial-news-sentiment-correlation\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9200 (\N{ALARM CLOCK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### Publisher Analysis:

# %%
# email addresses are used as publisher names
TSLA.extract_email_domains()
# Out:
# Top contributing email domains:
# publisher_domain
# benzinga.com    12
# Name: count, dtype: int64
