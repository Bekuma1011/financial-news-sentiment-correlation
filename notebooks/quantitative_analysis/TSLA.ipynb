# %%
import sys
from pathlib import Path

# Add project root to path (one-time setup)
project_root = str(Path().resolve().parent.parent)  # Goes up to project_root/
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.quantitative_analysis import StockAnalyzer

# %% [markdown]
# ##### create instance

# %%
# pass data 
TSLA_analyzer = StockAnalyzer(name="TSLA", filepath="../../data/yfinance_data/TSLA_historical_data.csv")

# %% [markdown]
# #### load_data

# %%
TSLA_analyzer.load_data()
# Out:
# Data loaded successfully.

# %% [markdown]
# #### Analysis Indicators with TA-Lib

# %%
TSLA_analyzer.calculate_indicators()
# Out:
# Technical indicators calculated.

# %%
TSLA_analyzer.df.head(40)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
# 2010-07-07  1.093333  1.108667  0.998667  1.053333   1.053333  103825500
# 2010-07-08  1.076000  1.168000  1.038000  1.164000   1.164000  115671000
# 2010-07-09  1.172000  1.193333  1.103333  1.160000   1.160000   60759000
# 2010-07-12  1.196667  1.204667  1.133333  1.136667   1.136667   33037500
# 2010-07-13  1.159333  1.242667  1.126667  1.209333   1.209333   40201500
# 2010-07-14  1.196000  1.343333  1.184000  1.322667   1.322667   62928000
# 2010-07-15  1.329333  1.433333  1.266667  1.326000   1.326000   56097000
# ...

# %%
TSLA_analyzer.df.tail(9)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-07-18  251.089996  257.140015  247.199997  249.229996  249.229996
# 2024-07-19  247.789993  249.440002  236.830002  239.199997  239.199997
# 2024-07-22  244.210007  253.210007  243.750000  251.509995  251.509995
# 2024-07-23  253.600006  255.759995  245.630005  246.380005  246.380005
# 2024-07-24  225.419998  225.990005  214.710007  215.990005  215.990005
# 2024-07-25  216.800003  226.000000  216.229996  220.250000  220.250000
# 2024-07-26  221.190002  222.279999  215.330002  219.800003  219.800003
# 2024-07-29  224.899994  234.270004  224.699997  232.100006  232.100006
# 2024-07-30  232.250000  232.410004  220.000000  222.619995  222.619995
#
#                Volume  Dividends  Stock Splits      SMA_20        RSI  \
# Date
# 2024-07-18  110869000        0.0           0.0  226.996500  66.005487
# 2024-07-19   87403900        0.0           0.0  229.877999  58.655486
# ...

# %% [markdown]
# #### Visualize the impact of different indicators on the stock price.

# %%
TSLA_analyzer.plot_sma()

# %%
TSLA_analyzer.plot_rsi()

# %%
TSLA_analyzer.plot_macd()
