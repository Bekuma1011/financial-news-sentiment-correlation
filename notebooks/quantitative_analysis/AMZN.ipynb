# %%
import sys
from pathlib import Path

# Add project root to path (one-time setup)
project_root = str(Path().resolve().parent.parent)  # Goes up to project_root/
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.quantitative_analysis import StockAnalyzer

# %% [markdown]
# ##### create instance

# %%
# pass data 
AMZN_analyzer = StockAnalyzer(name="AMZN", filepath="../../data/yfinance_data/AMZN_historical_data.csv")

# %% [markdown]
# #### load_data

# %%
AMZN_analyzer.load_data()
# Out:
# Data loaded successfully.

# %% [markdown]
# #### Analysis Indicators with TA-Lib

# %%
AMZN_analyzer.calculate_indicators()
# Out:
# Technical indicators calculated.

# %%
AMZN_analyzer.df.head(40)
# Out:
#                 Open      High       Low     Close  Adj Close      Volume  \
# Date
# 1997-05-15  0.121875  0.125000  0.096354  0.097917   0.097917  1443120000
# 1997-05-16  0.098438  0.098958  0.085417  0.086458   0.086458   294000000
# 1997-05-19  0.088021  0.088542  0.081250  0.085417   0.085417   122136000
# 1997-05-20  0.086458  0.087500  0.081771  0.081771   0.081771   109344000
# 1997-05-21  0.081771  0.082292  0.068750  0.071354   0.071354   377064000
# 1997-05-22  0.071875  0.072396  0.065625  0.069792   0.069792   235536000
# 1997-05-23  0.070313  0.076042  0.066667  0.075000   0.075000   318744000
# 1997-05-27  0.075521  0.082292  0.072917  0.079167   0.079167   173952000
# 1997-05-28  0.081250  0.081771  0.076563  0.076563   0.076563    91488000
# 1997-05-29  0.077083  0.077083  0.073958  0.075260   0.075260    69456000
# 1997-05-30  0.075000  0.075521  0.073958  0.075000   0.075000    51888000
# 1997-06-02  0.075521  0.076563  0.075000  0.075521   0.075521    11832000
# ...

# %%
AMZN_analyzer.df.tail(9)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-07-18  189.589996  189.679993  181.449997  183.750000  183.750000
# 2024-07-19  181.139999  184.929993  180.110001  183.130005  183.130005
# 2024-07-22  185.000000  185.059998  182.479996  182.550003  182.550003
# 2024-07-23  184.100006  189.389999  183.559998  186.410004  186.410004
# 2024-07-24  183.199997  185.449997  180.410004  180.830002  180.830002
# 2024-07-25  182.910004  183.899994  176.800003  179.850006  179.850006
# 2024-07-26  180.389999  183.190002  180.240005  182.500000  182.500000
# 2024-07-29  183.839996  184.750000  182.380005  183.199997  183.199997
# 2024-07-30  184.720001  185.860001  179.380005  181.710007  181.710007
#
#               Volume  Dividends  Stock Splits    SMA_20        RSI      MACD  \
# Date
# 2024-07-18  51043600        0.0           0.0  193.5985  38.016792  0.949405
# 2024-07-19  43081800        0.0           0.0  193.4500  37.272419  0.150489
# ...

# %% [markdown]
# #### Visualize the impact of different indicators on the stock price.

# %%
AMZN_analyzer.plot_sma()

# %%
AMZN_analyzer.plot_rsi()

# %%
AMZN_analyzer.plot_macd()
