# %%
import sys
from pathlib import Path

# Add project root to path (one-time setup)
project_root = str(Path().resolve().parent.parent)  # Goes up to project_root/
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.quantitative_analysis import StockAnalyzer

# %% [markdown]
# ##### create instance

# %%
# pass data 
MSFT_analyzer = StockAnalyzer(name="MSFT", filepath="../../data/yfinance_data/MSFT_historical_data.csv")

# %% [markdown]
# #### load_data

# %%
MSFT_analyzer.load_data()
# Out:
# Data loaded successfully.

# %% [markdown]
# #### Analysis Indicators with TA-Lib

# %%
MSFT_analyzer.calculate_indicators()
# Out:
# Technical indicators calculated.

# %%
MSFT_analyzer.df.head(40)
# Out:
#                 Open      High       Low     Close  Adj Close      Volume  \
# Date
# 1986-03-13  0.088542  0.101563  0.088542  0.097222   0.059946  1031788800
# 1986-03-14  0.097222  0.102431  0.097222  0.100694   0.062087   308160000
# 1986-03-17  0.100694  0.103299  0.100694  0.102431   0.063158   133171200
# 1986-03-18  0.102431  0.103299  0.098958  0.099826   0.061552    67766400
# 1986-03-19  0.099826  0.100694  0.097222  0.098090   0.060482    47894400
# 1986-03-20  0.098090  0.098090  0.094618  0.095486   0.058876    58435200
# 1986-03-21  0.095486  0.097222  0.091146  0.092882   0.057270    59990400
# 1986-03-24  0.092882  0.092882  0.089410  0.090278   0.055665    65289600
# 1986-03-25  0.090278  0.092014  0.089410  0.092014   0.056735    32083200
# 1986-03-26  0.092014  0.095486  0.091146  0.094618   0.058341    22752000
# 1986-03-27  0.094618  0.096354  0.094618  0.096354   0.059411    16848000
# 1986-03-31  0.096354  0.096354  0.093750  0.095486   0.058876    12873600
# ...

# %%
MSFT_analyzer.df.tail(9)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-07-18  444.339996  444.649994  434.399994  440.369995  439.577698
# 2024-07-19  433.100006  441.140015  432.000000  437.109985  436.323547
# 2024-07-22  441.790009  444.600006  438.910004  442.940002  442.143066
# 2024-07-23  443.899994  448.390015  443.100006  444.850006  444.049652
# 2024-07-24  440.450012  441.480011  427.589996  428.899994  428.128326
# 2024-07-25  428.799988  429.799988  417.510010  418.399994  417.647217
# 2024-07-26  418.200012  428.920013  417.269989  425.269989  424.504852
# 2024-07-29  431.579987  432.149994  424.700012  426.730011  425.962250
# 2024-07-30  427.720001  429.049988  417.359985  422.920013  422.159119
#
#               Volume  Dividends  Stock Splits      SMA_20        RSI  \
# Date
# 2024-07-18  20794800        0.0           0.0  453.902501  43.052471
# 2024-07-19  20940400        0.0           0.0  453.473000  40.559301
# ...

# %% [markdown]
# #### Visualize the impact of different indicators on the stock price.

# %%
MSFT_analyzer.plot_sma()

# %%
MSFT_analyzer.plot_rsi()

# %%
MSFT_analyzer.plot_macd()
