# %%
import sys
from pathlib import Path

# Add project root to path (one-time setup)
project_root = str(Path().resolve().parent.parent)  # Goes up to project_root/
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.quantitative_analysis import StockAnalyzer

# %% [markdown]
# ##### create instance

# %%
# pass data 
META_analyzer = StockAnalyzer(name="META", filepath="../../data/yfinance_data/META_historical_data.csv")

# %% [markdown]
# #### load_data

# %%
META_analyzer.load_data()
# Out:
# Data loaded successfully.

# %% [markdown]
# #### Analysis Indicators with TA-Lib

# %%
META_analyzer.calculate_indicators()
# Out:
# Technical indicators calculated.

# %%
META_analyzer.df.head(40)
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2012-12-12  28.000000  28.139999  27.370001  27.580000  27.523441   46704200
# 2012-12-13  27.590000  28.750000  27.430000  28.240000  28.182087   81051600
# 2012-12-14  28.180000  28.330000  26.760000  26.809999  26.755020   91631600
# 2012-12-17  26.770000  27.000000  26.320000  26.750000  26.695143   57742500
# 2012-12-18  26.959999  27.910000  26.900000  27.709999  27.653173   60512900
# 2012-12-19  27.830000  28.219999  26.950001  27.410000  27.353790   61390300
# 2012-12-20  27.490000  27.600000  27.129999  27.360001  27.303892   35574800
# 2012-12-21  26.660000  27.010000  26.120001  26.260000  26.206148   54555200
# 2012-12-24  26.500000  26.959999  26.200001  26.930000  26.874775   28230100
# 2012-12-26  27.030001  27.180000  26.379999  26.510000  26.455635   33175400
# 2012-12-27  26.549999  26.799999  25.520000  26.049999  25.996578   43481700
# ...

# %%
META_analyzer.df.tail(9)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-07-18  475.000000  479.239990  464.540009  475.850006  475.850006
# 2024-07-19  476.059998  486.709991  475.709991  476.790009  476.790009
# 2024-07-22  486.579987  492.059998  483.899994  487.399994  487.399994
# 2024-07-23  489.839996  495.220001  487.720001  488.690002  488.690002
# 2024-07-24  472.309998  476.299988  460.579987  461.269989  461.269989
# 2024-07-25  463.260010  463.549988  442.649994  453.410004  453.410004
# 2024-07-26  464.200012  469.769989  459.420013  465.700012  465.700012
# 2024-07-29  469.880005  473.959991  465.019989  465.709991  465.709991
# 2024-07-30  467.000000  472.730011  456.700012  463.190002  463.190002
#
#               Volume  Dividends  Stock Splits      SMA_20        RSI  \
# Date
# 2024-07-18  19267200        0.0           0.0  506.815500  40.149101
# 2024-07-19  15149400        0.0           0.0  505.570000  40.602613
# ...

# %% [markdown]
# #### Visualize the impact of different indicators on the stock price.

# %%
META_analyzer.plot_sma()

# %%
META_analyzer.plot_rsi()

# %%
META_analyzer.plot_macd()
