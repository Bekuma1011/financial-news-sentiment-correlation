# %%
import sys
from pathlib import Path

# Add project root to path (one-time setup)
project_root = str(Path().resolve().parent.parent)  # Goes up to project_root/
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.quantitative_analysis import StockAnalyzer

# %% [markdown]
# ##### create instance

# %%
# pass data 
GOOG_analyzer = StockAnalyzer(name="GOOG",filepath="../../data/yfinance_data/GOOG_historical_data.csv")

# %% [markdown]
# #### load_data

# %%
GOOG_analyzer.load_data()
# Out:
# Data loaded successfully.

# %% [markdown]
# #### Analysis Indicators with TA-Lib

# %%
GOOG_analyzer.calculate_indicators()
# Out:
# Technical indicators calculated.

# %%
GOOG_analyzer.df.head(40)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2004-08-19  2.490664  2.591785  2.390042  2.499133   2.496292  897427216
# 2004-08-20  2.515820  2.716817  2.503118  2.697639   2.694573  458857488
# 2004-08-23  2.758411  2.826406  2.716070  2.724787   2.721690  366857939
# 2004-08-24  2.770615  2.779581  2.579581  2.611960   2.608991  306396159
# 2004-08-25  2.614201  2.689918  2.587302  2.640104   2.637103  184645512
# 2004-08-26  2.613952  2.688672  2.606729  2.687676   2.684621  142572401
# 2004-08-27  2.692408  2.705360  2.632383  2.643840   2.640835  124826132
# 2004-08-30  2.622171  2.627402  2.540727  2.540727   2.537839  104429967
# 2004-08-31  2.547950  2.583068  2.544463  2.549693   2.546795   98825037
# 2004-09-01  2.557912  2.564637  2.482445  2.496891   2.494053  183633734
# 2004-09-02  2.470490  2.549693  2.464263  2.528273   2.525399  303810504
# 2004-09-03  2.514326  2.534002  2.473728  2.490913   2.488082  103538639
# ...

# %%
GOOG_analyzer.df.tail(9)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-07-18  183.539993  184.050003  178.210007  179.220001  179.220001
# 2024-07-19  180.369995  181.970001  178.860001  179.389999  179.389999
# 2024-07-22  182.350006  184.300003  181.899994  183.350006  183.350006
# 2024-07-23  183.839996  185.220001  183.330002  183.600006  183.600006
# 2024-07-24  175.389999  177.949997  173.570007  174.369995  174.369995
# 2024-07-25  174.250000  175.199997  169.050003  169.160004  169.160004
# 2024-07-26  168.770004  169.839996  165.865005  168.679993  168.679993
# 2024-07-29  170.500000  172.160004  169.720001  171.130005  171.130005
# 2024-07-30  171.830002  172.949997  170.119995  171.860001  171.860001
#
#               Volume  Dividends  Stock Splits      SMA_20        RSI  \
# Date
# 2024-07-18  17877200        0.0           0.0  185.681500  42.356721
# 2024-07-19  14485900        0.0           0.0  185.765500  42.709312
# ...

# %% [markdown]
# #### Visualize the impact of different indicators on the stock price.

# %%
GOOG_analyzer.plot_sma()

# %%
GOOG_analyzer.plot_rsi()

# %%
GOOG_analyzer.plot_macd()
